# %% [raw]
# ---
# title: "ICIJ Offshore Leaks"
# subtitle: "Soziale Netzwerkanalyse von Schweizer Offshore Firmen in den Pandora Papers"
# author:
#   - name: Florin Barbisch
#     email: florin.barbisch@students.fhnw.ch
#   - name: Gabriel Torres Gamez
#     affiliation:
#     email: gabriel.torresgamez@students.fhnw.ch
#   - name: Tobias Buess
#     email: tobias.buess@students.fhnw.ch
# toc: true
# toc-title: "Inhaltsverzeichnis"
# number-sections: false
# output-file: "praesentation.html"
# format:
#   revealjs:
#     auto-stretch: true
#     html-math-method: katex
#     embed-resources: true
#     slide-number: true
#     smaller: true
#     logo: https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/FHNW_Logo.svg/2560px-FHNW_Logo.svg.png
#     footer: "Studiengang B.Sc. Data Science, Fachhochschule Nordwestschweiz FHNW"
# ---

# %% [markdown]
# ## Explorative Datenanalyse
#
# ::: {style="text-align: center;"}
# ![Nodestruktur von ICIJ Offshore Leaks Database](attachment:image-2.png){width=85%}
# :::
